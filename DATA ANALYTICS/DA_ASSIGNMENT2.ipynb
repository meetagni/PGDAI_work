# %%
import numpy as np
import pandas as pd
pokemon=pd.read_csv(r"C:\Users\Meet\Downloads\pokemon.csv")
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %% [markdown]
# ### 1. Find the names of legendary pokemon

# %%
pokemon[pokemon['is_legendary'] == 1].groupby(['name']).first()
# Out:
#                                    abilities  against_bug  against_dark  \
# name
# Arceus                         ['Multitype']          1.0           1.0
# Articuno          ['Pressure', 'Snow Cloak']          0.5           1.0
# Azelf                           ['Levitate']          2.0           2.0
# Buzzwole                     ['Beast Boost']          0.5           0.5
# Celebi                      ['Natural Cure']          4.0           2.0
# ...                                      ...          ...           ...
# Xurkitree                    ['Beast Boost']          1.0           1.0
# Yveltal                        ['Dark Aura']          1.0           0.5
# Zapdos                ['Pressure', 'Static']          0.5           1.0
# Zekrom                          ['Teravolt']          1.0           1.0
# Zygarde    ['Aura Break', 'Power Construct']          1.0           1.0
#
#            against_dragon  against_electric  against_fairy  against_fight  \
# name
# ...

# %% [markdown]
# ### 2. Get pokemon name from user then print its details

# %%
usergiven=input("Enter name of a pokemon: ")
n=usergiven.capitalize()
pokemon[pokemon['name'] == n]
# Out:
# Enter name of a pokemon: charizard
#                   abilities  against_bug  against_dark  against_dragon  \
# 5  ['Blaze', 'Solar Power']         0.25           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 5               2.0            0.5            0.5           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 5             1.0            1.0  ...             88.1               6
#
#    sp_attack  sp_defense  speed  type1   type2  weight_kg  generation  \
# 5        159         115    100   fire  flying       90.5           1
#
#    is_legendary
# 5             0
#
# [1 rows x 41 columns]

# %% [markdown]
# ### 3. Find the pokemon with maximum base stat total. If tie exists, then check if legendary. If tie still exists, check generation=3

# %%
max_total=pokemon[pokemon['base_total']==max(pokemon['base_total'])]
max_total[max_total['generation']==3]
# Out:
#         abilities  against_bug  against_dark  against_dragon  \
# 383  ['Air Lock']          0.5           1.0             2.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 383               1.0            2.0            0.5           0.5
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 383             1.0            1.0  ...              NaN             384
#
#      sp_attack  sp_defense  speed   type1   type2  weight_kg  generation  \
# 383        180         100    115  dragon  flying      206.5           3
#
#      is_legendary
# 383             1
#
# [1 rows x 41 columns]

# %% [markdown]
# ### 4. Print generation 6 pokemon

# %%
pokemon[pokemon['generation'] == 6].groupby(['name']).first()
# Out:
#                                                   abilities  against_bug  \
# name
# Aegislash                                 ['Stance Change']         0.25
# Amaura                      ['Refrigerate', 'Snow Warning']         1.00
# Aromatisse                         ['Healer', 'Aroma Veil']         0.50
# Aurorus                     ['Refrigerate', 'Snow Warning']         1.00
# Avalugg                 ['Own Tempo', 'Ice Body', 'Sturdy']         1.00
# ...                                                     ...          ...
# Vivillon    ['Shield Dust', 'Compoundeyes', 'Friend Guard']         0.50
# Volcanion                                  ['Water Absorb']         0.50
# Xerneas                                      ['Fairy Aura']         0.50
# Yveltal                                       ['Dark Aura']         1.00
# Zygarde                   ['Aura Break', 'Power Construct']         1.00
#
#             against_dark  against_dragon  against_electric  against_fairy  \
# name
# ...
